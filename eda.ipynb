# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("C:\Source\Concept-Drift-NHANES-Diabetes-Classification\data\\X_train.csv", index_col=0)
y_train = pd.read_csv("C:\Source\Concept-Drift-NHANES-Diabetes-Classification\data\\y_train.csv", index_col=0)

# %%
X_train.shape
# Out:
# (77396, 12)

# %%
y_train.shape
# Out:
# (77396, 1)

# %%
X_train.head()
# Out:
#    Age    LDL Chol   HDL Chol    Chloride  Total Chol        GGT        AST  \
# 0    7  108.710285  51.000000  103.345424       119.0  26.740553  24.945995
# 1   31  139.000000  37.000000  102.000000       191.0  23.000000  27.000000
# 2   21  133.000000  44.000000  103.000000       216.0  15.000000  26.000000
# 3   51  108.710285  56.000000  103.000000       203.0  11.000000  21.000000
# 4   55  108.710285  53.277988  101.000000       165.0  10.000000  44.000000
#
#    Hemoglobin  Weight    BMI        ALP        ALT
# 0        12.7    33.1  17.50  87.745839  23.851419
# 1        17.2    99.0  31.20  90.000000  30.000000
# 2        15.1    55.6  20.80  77.000000  20.000000
# 3        14.4    67.1  23.10  73.000000  16.000000
# 4        14.1    55.9  18.61  87.745839  33.000000

# %%
y_train.head()
# Out:
#    Diabetes
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0

# %%
#combine for exploration
df = pd.concat([X_train, y_train], axis=1)

# %%
df.head()
# Out:
#    Age    LDL Chol   HDL Chol    Chloride  Total Chol        GGT        AST  \
# 0    7  108.710285  51.000000  103.345424       119.0  26.740553  24.945995
# 1   31  139.000000  37.000000  102.000000       191.0  23.000000  27.000000
# 2   21  133.000000  44.000000  103.000000       216.0  15.000000  26.000000
# 3   51  108.710285  56.000000  103.000000       203.0  11.000000  21.000000
# 4   55  108.710285  53.277988  101.000000       165.0  10.000000  44.000000
#
#    Hemoglobin  Weight    BMI        ALP        ALT  Diabetes
# 0        12.7    33.1  17.50  87.745839  23.851419         0
# 1        17.2    99.0  31.20  90.000000  30.000000         0
# 2        15.1    55.6  20.80  77.000000  20.000000         0
# 3        14.4    67.1  23.10  73.000000  16.000000         1
# 4        14.1    55.9  18.61  87.745839  33.000000         0

# %%
plt.figure(figsize=(12,8))
sns.histplot(df['Age'], bins=30).set_title("Participant Count by Age")
plt.show()

# %%
df.hist(bins=30, figsize=(20,20))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['LDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df[df['LDL Chol']<125]['LDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['LDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df[df['LDL Chol']<200]['LDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['HDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['HDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df[df['HDL Chol']<120]['HDL Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['Chloride'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['Chloride'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['Total Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['Total Chol'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['GGT'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['GGT'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['AST'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['AST'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['Hemoglobin'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['Hemoglobin'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['Weight'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['Weight'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['BMI'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['BMI'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['ALP'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['ALP'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.boxplot(x = df['Diabetes'], y = df['ALT'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.violinplot(x = df['Diabetes'], y = df['ALT'], ax=ax)
plt.show()
